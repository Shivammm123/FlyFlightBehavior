# %%
from fly_analysis import braidz
from fly_analysis import filtering
from fly_analysis.processing import extract_stimulus_centered_data
import numpy as np
from matplotlib import pyplot as plt
from fly_analysis.plotting import plot_mean_and_std
from fly_analysis.plotting import plot_trajectory
from datetime import datetime
from scipy import stats
from scipy.stats import mannwhitneyu
from scipy.stats import wilcoxon
from scipy.stats import kruskal
from scipy.stats import friedmanchisquare
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from fly_analysis.trajectory import heading_direction_diff
import matplotlib.ticker as ticker

# %%
df1, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240910_140319.braidz")
df1,csvs["opto"]
data1 = extract_stimulus_centered_data(df1, csvs["opto"])
list(data1)
AngV1 = data1['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240910_140319.braidz using pyarrow

# %%
df2, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240912_140309.braidz")
df2,csvs["opto"]
data2 = extract_stimulus_centered_data(df2, csvs["opto"])
list(data2)
AngV2 = data2['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240912_140309.braidz using pyarrow

# %%
df3, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240914_140037.braidz")
df3,csvs["opto"]
data3 = extract_stimulus_centered_data(df3, csvs["opto"])
list(data3)
AngV3 = data3['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240914_140037.braidz using pyarrow

# %%
AngV_J73_Gal4 = np.concatenate([AngV2, AngV3])

# %%
df4, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240911_151201.braidz")
df4,csvs["opto"]
data4 = extract_stimulus_centered_data(df4, csvs["opto"])
list(data4)
AngV4 = data4['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240911_151201.braidz using pyarrow

# %%
df5, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240913_141235.braidz")
df5,csvs["opto"]
data5 = extract_stimulus_centered_data(df5, csvs["opto"])
AngV5 = data5['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240913_141235.braidz using pyarrow

# %%
df6, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240915_140001.braidz")
df6,csvs["opto"]
data6 = extract_stimulus_centered_data(df6, csvs["opto"])
list(data6)
AngV6 = data6['angular_velocity']
print(AngV6)
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240915_140001.braidz using pyarrow
# [array([-2.19488280e+03, -1.14381708e+03, -5.64235712e+02, -2.20319419e+02,
#         6.19422931e+01,  1.43478323e+02,  1.69383130e+02,  2.88589199e+02,
#         3.27926779e+02,  2.48769045e+02,  1.89946979e+02,  2.87379207e+02,
#         2.94222114e+02,  2.38269322e+02,  1.94926610e+02,  1.48229419e+02,
#         1.59975448e+02,  1.57097546e+02,  1.38447030e+02,  1.23980242e+02,
#         1.34896258e+02,  1.58770810e+02,  1.81272851e+02,  1.29789428e+02,
#         7.92483523e+01,  3.17804151e+01,  4.25930363e+01,  2.66781099e+01,
#        -3.28832569e+01,  5.98670901e-01,  1.36575206e+02,  2.00912004e+02,
#         2.03379650e+01, -2.07140451e+02, -1.34967719e+02, -6.47771226e+01,
#        -9.61185969e+01,  8.86387760e+01,  6.56146045e+01,  2.12570756e+01,
#        -8.75873828e+01, -1.31769769e+02, -1.10898264e+01, -1.16633932e+02,
# ...

# %%
AngV_J74_Gal4 = np.concatenate([AngV4, AngV5, AngV6])

# %%
df7, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240924_161949.braidz")
df7,csvs["opto"]
data7= extract_stimulus_centered_data(df7, csvs["opto"])
AngV7 = data7['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240924_161949.braidz using pyarrow

# %%
df15, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241206_140404.braidz")
df15,csvs["opto"]
data15= extract_stimulus_centered_data(df15, csvs["opto"])
AngV15 = data15['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241206_140404.braidz using pyarrow

# %%
AngV_J64 = np.concatenate([AngV7, AngV15])

# %%
df8, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240927_140036.braidz")
df8,csvs["opto"]
data8 = extract_stimulus_centered_data(df8, csvs["opto"])
list(data8)
AngV8 = data8['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240927_140036.braidz using pyarrow

# %%
df9, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240925_141823.braidz")
df9, csvs["opto"]
data9 = extract_stimulus_centered_data(df9, csvs["opto"])
list(data9)
AngV9 = data9['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240925_141823.braidz using pyarrow

# %%
AngV_J72_Gal4 = np.concatenate([AngV8, AngV9])

# %%
df10, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240926_135859.braidz")
df10,csvs["opto"]
data10 = extract_stimulus_centered_data(df10, csvs["opto"])
AngV10 = data10['angular_velocity']
print,csvs["opto"]
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240926_135859.braidz using pyarrow
# (<function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#      obj_id    frame         x         y         z      xvel      yvel  \
#  0      449   216710  0.017129 -0.017509  0.203103 -0.169622  0.102753
#  1      485  1110261 -0.000010  0.023401  0.200175  0.108191 -0.192746
#  2      639  1438043 -0.011657 -0.022109  0.165243 -0.290496  0.306899
#  3      689  1579648 -0.021913  0.011873  0.162177  0.359121  0.117324
#  4      886  1757252 -0.006331 -0.023060  0.100869  0.133852  0.415389
#  ..     ...      ...       ...       ...       ...       ...       ...
#  74   10190  6348831 -0.023301  0.005288  0.184275  0.216214 -0.156911
#  75   10378  6556341 -0.009875 -0.022049  0.158605  0.271655  0.157720
#  76   10563  6780699  0.010534 -0.020554  0.216060  0.107285  0.394060
#  77   10935  7628291 -0.009270 -0.009106  0.249825 -0.132590 -0.097824
# ...

# %%
df11, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20240928_140534.braidz")
df11,csvs["opto"]
data11 = extract_stimulus_centered_data(df11, csvs["opto"])
AngV11 = data11['angular_velocity']
print,csvs["opto"]
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20240928_140534.braidz using pyarrow
# (<function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#       obj_id    frame         x         y         z      xvel      yvel  \
#  0         5    37865  0.020186 -0.013963  0.167810  0.035963  0.134354
#  1       216    98245 -0.023953  0.000455  0.146455  0.118131 -0.028846
#  2       237   764962 -0.024135 -0.005841  0.159454  0.062169 -0.052586
#  3       237   765605  0.019289 -0.015816  0.189555 -0.096897  0.057142
#  4       239  1146023 -0.022306  0.008993  0.245661  0.128263 -0.160404
#  ..      ...      ...       ...       ...       ...       ...       ...
#  184   76857  7499065 -0.014037 -0.019724  0.185217  0.128419  0.186662
#  185   76954  7554245  0.020875  0.007778  0.112703 -0.159311 -0.304856
#  186   77014  7634033  0.006398  0.023138  0.189391 -0.107732 -0.290316
#  187   77850  8305993  0.020850 -0.005480  0.215375 -0.451022  0.302511
# ...

# %%
AngV_J76_Gal4 = np.concatenate([AngV10, AngV11])

# %%
df12, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241026_135608.braidz")
df12,csvs["opto"]
data12 = extract_stimulus_centered_data(df12, csvs["opto"])
AngV12 = data12['angular_velocity']
print,csvs["opto"]
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241026_135608.braidz using pyarrow
# (<function print(*args, sep=' ', end='\n', file=None, flush=False)>,
#      obj_id    frame         x         y         z      xvel      yvel  \
#  0        8    87430 -0.024528  0.004497  0.098375  0.100080 -0.017478
#  1      741   251945  0.014876 -0.019766  0.150706 -0.080260  0.102593
#  2      772   253488 -0.009392  0.022058  0.172383  0.201556 -0.191315
#  3     1272  1279240 -0.020407 -0.012762  0.117487  0.181614 -0.049244
#  4     1279  1280030  0.017633  0.015687  0.126543 -0.228163 -0.111576
#  5     1392  1585333 -0.017183 -0.001246  0.079323 -0.187458  0.100651
#  6     1623  1699724 -0.000126  0.024246  0.173987  0.063553  0.103773
#  7     4696  2014701  0.019025 -0.016099  0.051627 -0.103147  0.214594
#  8     6271  2124464 -0.001769  0.024054  0.072205  0.233925 -0.077979
#  9    12980  2384895 -0.004326  0.020103  0.075825 -0.024255 -0.401242
# ...

# %%
df13, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241029_142122.braidz")
df13,csvs["opto"]
data13 = extract_stimulus_centered_data(df13, csvs["opto"])
AngV13 = data13['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241029_142122.braidz using pyarrow

# %%
df14, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241030_135421.braidz")
df14,csvs["opto"]
data14 = extract_stimulus_centered_data(df14, csvs["opto"])
AngV14 = data14['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241030_135421.braidz using pyarrow

# %%
AngV_J20 = np.concatenate([AngV13, AngV14])

# %%
df16, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241103_140002.braidz")
df16,csvs["opto"]
data16 = extract_stimulus_centered_data(df16, csvs["opto"])
AngV16 = data16['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241103_140002.braidz using pyarrow

# %%
df17, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241111_151728.braidz")
df17,csvs["opto"]
data17 = extract_stimulus_centered_data(df17, csvs["opto"])
AngV17 = data17['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241111_151728.braidz using pyarrow

# %%
AngV_J36 = np.concatenate([AngV16, AngV17])

# %%
df18, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241109_185224.braidz")
df18,csvs["opto"]
data18 = extract_stimulus_centered_data(df18, csvs["opto"])
AngV18 = data18['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241109_185224.braidz using pyarrow

# %%
df19, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241109_185224.braidz")
df19,csvs["opto"]
data19 = extract_stimulus_centered_data(df19, csvs["opto"])
AngV19 = data19['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241109_185224.braidz using pyarrow

# %%
df20, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241209_141918.braidz")
df20,csvs["opto"]
data20 = extract_stimulus_centered_data(df20, csvs["opto"])
AngV20 = data20['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241209_141918.braidz using pyarrow

# %%
df21, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241211_140152.braidz")
df21,csvs["opto"]
data21 = extract_stimulus_centered_data(df21, csvs["opto"])
AngV21 = data21['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241211_140152.braidz using pyarrow

# %%
AngV_J31 = np.concatenate([AngV19, AngV20, AngV21])

# %%
df22, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241210_140025.braidz")
df22,csvs["opto"]
data22 = extract_stimulus_centered_data(df22, csvs["opto"])
AngV22 = data22['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241210_140025.braidz using pyarrow

# %%
df23, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241212_145945.braidz")
df23,csvs["opto"]
data23 = extract_stimulus_centered_data(df23, csvs["opto"])
AngV23 = data23['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241212_145945.braidz using pyarrow

# %%
df24, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241214_141136.braidz")
df24,csvs["opto"]
data24 = extract_stimulus_centered_data(df24, csvs["opto"])
AngV24 = data24['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241214_141136.braidz using pyarrow

# %%
AngV_J59 = np.concatenate([AngV22, AngV23, AngV24])

# %%
df25, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241220_140225.braidz")
df25,csvs["opto"]
data25 = extract_stimulus_centered_data(df25, csvs["opto"])
AngV25 = data25['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241220_140225.braidz using pyarrow

# %%
df26, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241222_140931.braidz")
df26,csvs["opto"]
data26 = extract_stimulus_centered_data(df26, csvs["opto"])
AngV26 = data26['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241222_140931.braidz using pyarrow

# %%
AngV_J71 = np.concatenate([AngV25, AngV26])

# %%
df27, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241221_141940.braidz")
df27,csvs["opto"]
data27 = extract_stimulus_centered_data(df27, csvs["opto"])
AngV27 = data27['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241221_141940.braidz using pyarrow

# %%
df28, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241223_140135.braidz")
df28,csvs["opto"]
data28 = extract_stimulus_centered_data(df28, csvs["opto"])
AngV28 = data28['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241223_140135.braidz using pyarrow

# %%
df29, csvs = braidz.read_braidz(r"C:\\Users\\pandey\\Desktop\\Braidz Files\\20241227_135805.braidz")
df29,csvs["opto"]
data29 = extract_stimulus_centered_data(df29, csvs["opto"])
AngV29 = data29['angular_velocity']
# Out:
# Reading C:\\Users\\pandey\\Desktop\\Braidz Files\\20241227_135805.braidz using pyarrow

# %%
AngV_J75 = np.concatenate([AngV27, AngV28, AngV29])

# %%
fig, ax = plt.subplots(figsize=(14, 10))

plot_mean_and_std(np.abs(AngV_J73_Gal4), ax=ax, label='J73-(DNa05/07)', color='red')
plot_mean_and_std(np.abs(AngV_J72_Gal4), ax=ax, label='J72-(DNa05/07)', color='orange')
plot_mean_and_std(np.abs(AngV_J64), ax=ax, label='J64-empty_splitGal4', color='black')
plot_mean_and_std(np.abs(AngV_J76_Gal4), ax=ax, label='J76-(DNp11)', color='purple')
plot_mean_and_std(np.abs(AngV_J20), ax=ax, label='J20-(DNa07)', color='green')
plot_mean_and_std(np.abs(AngV_J36), ax=ax, label='J36-(DNa08)', color='brown')
plot_mean_and_std(np.abs(AngV_J31), ax=ax, label='J31-(DNb01)', color='pink')
plot_mean_and_std(np.abs(AngV_J59), ax=ax, label='J59-(DNp06)', color='white')
plot_mean_and_std(np.abs(AngV_J71), ax=ax, label='J71-(DNa10)', color='olive')
plot_mean_and_std(np.abs(AngV_J75), ax=ax, label='J75-(DNa04/10)', color='cyan')


ax.set_xlabel("frame", fontsize = 20)
ax.set_ylabel("angvel (degree/sec)")
ax.set_title("Ang_Vel Plot_Comparison ")

ax.yaxis.set_major_locator(ticker.MultipleLocator(500))

ax.axvspan(50, 80, color='red', alpha=0.1)
plt.legend(title="Experiment Index", fontsize=12, title_fontsize=14)

plt.title("Angular Velocity Comparison", fontsize=25)
plt.ylabel("angvel (degree/sec)", fontsize=22)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(False)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 10))

# Plot the data
plot_mean_and_std(np.abs(AngV_J74_Gal4), ax=ax, label='J74-(DNa05/03)', color='blue')
plot_mean_and_std(np.abs(AngV_J73_Gal4), ax=ax, label='J73-(DNa05/07)', color='red')
plot_mean_and_std(np.abs(AngV_J72_Gal4), ax=ax, label='J72-(DNa05/07)', color='orange')
plot_mean_and_std(np.abs(AngV_J64), ax=ax, label='J64-empty_splitGal4', color='black')
plot_mean_and_std(np.abs(AngV_J76_Gal4), ax=ax, label='J76-(DNp11)', color='purple')
plot_mean_and_std(np.abs(AngV_J20), ax=ax, label='J20-(DNa07)', color='green')
plot_mean_and_std(np.abs(AngV_J36), ax=ax, label='J36-(DNa08)', color='brown')
plot_mean_and_std(np.abs(AngV_J31), ax=ax, label='J31-(DNb01)', color='pink')
plot_mean_and_std(np.abs(AngV_J59), ax=ax, label='J59-(DNp06)', color='magenta')  # Changed white to teal for visibility
plot_mean_and_std(np.abs(AngV_J71), ax=ax, label='J71-(DNa10)', color='olive')
plot_mean_and_std(np.abs(AngV_J75), ax=ax, label='J75-(DNa04/10)', color='cyan')

# Adjust x-axis labels to milliseconds
num_frames = np.arange(0, len(AngV_J74_Gal4))  # Assuming all datasets have the same frame count
milliseconds = num_frames * 10  # Convert frames to milliseconds

ax.set_xticks(np.arange(0, len(milliseconds), step=20))  # Customize tick interval
ax.set_xticklabels(milliseconds[::20])  # Set the labels in milliseconds

# Add labels and formatting
ax.set_xlabel("Time (ms)", fontsize=20)
ax.set_ylabel("Angular Velocity (degree/sec)", fontsize=22)
ax.set_title("Angular Velocity Comparison", fontsize=25)

ax.yaxis.set_major_locator(ticker.MultipleLocator(500))
ax.axvspan(50, 80, color='red', alpha=0.1)
plt.legend(title="Experiment Index", fontsize=12, title_fontsize=14)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(False)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate mean and std, using absolute values
def get_mean_and_std(arr, abs_value=True):
    if abs_value:
        arr = np.abs(arr)
    mean = np.mean(arr, axis=0)
    std = np.std(arr, axis=0)
    return mean, std

fig, ax = plt.subplots(figsize=(14, 10))

# Get mean values using absolute values
mean_J74, _ = get_mean_and_std(AngV_J74_Gal4)  # We won't need std, so using _
mean_J73, _ = get_mean_and_std(AngV_J73_Gal4)
mean_J72, _ = get_mean_and_std(AngV_J72_Gal4)
mean_J64, _ = get_mean_and_std(AngV_J64)
mean_J76, _ = get_mean_and_std(AngV_J76_Gal4)
mean_J31, _ = get_mean_and_std(AngV_J31)
mean_J36, _ = get_mean_and_std(AngV_J36)
mean_J59, _ = get_mean_and_std(AngV_J59)
mean_J71, _ = get_mean_and_std(AngV_J71)
mean_J20, _ = get_mean_and_std(AngV_J20)
mean_J75, _ = get_mean_and_std(AngV_J75)


# Generate x values in milliseconds
x_ms = np.arange(len(mean_J74)) * 0.01 * 1000

# Plot manually using calculated mean (without shadows)
ax.plot(x_ms, mean_J74, label='(DNa05/03)', color='blue')
ax.plot(x_ms, mean_J73, label='(DNa05/07)', color='red')
ax.plot(x_ms, mean_J72, label='(DNa05/07)', color='orange')
ax.plot(x_ms, mean_J64, label='empty_splitGal4', color='black')
ax.plot(x_ms, mean_J76, label='(DNp11)', color='brown')
ax.plot(x_ms, mean_J31, label='(DNb01)', color='green')
ax.plot(x_ms, mean_J36, label='(DNa08)', color='cyan')
ax.plot(x_ms, mean_J59, label='(DNp06)', color='olive')
ax.plot(x_ms, mean_J20, label='(DNa07)', color='grey')
ax.plot(x_ms, mean_J71, label='(DNa10)', color='purple')
ax.plot(x_ms, mean_J75, label='(DNa04/10)', color='pink')

# Set x and y axis labels and title
ax.set_xlabel("Time (ms)", fontsize=20)
ax.set_ylabel("Angular Velocity (degree/sec)", fontsize=22)
ax.set_title("Angular Velocity Comparison", fontsize=25)

# Adjust y-axis ticks
ax.yaxis.set_major_locator(plt.MultipleLocator(500))

# Highlight region between 50 and 80 frames (convert to ms)
ax.axvspan(50 * 0.01 * 1000, 80 * 0.01 * 1000, color='red', alpha=0.1)

# Legend settings
plt.legend(title="Experiment Index", fontsize=16, title_fontsize=18)

# Tick formatting
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# Disable grid
plt.grid(False)

# Show the plot
plt.show()

# %%
# Convert lists to NumPy arrays if they aren't already arrays
AngV_J74_Gal4 = np.array(AngV_J74_Gal4)
AngV_J73_Gal4 = np.array(AngV_J73_Gal4)
AngV_J64 = np.array(AngV_J64)
AngV_J72_Gal4 = np.array(AngV_J72_Gal4)
AngV_J74_Gal4 = np.array(AngV_J76_Gal4)

# Flatten the arrays if needed (if they are multidimensional)
AngV_J74_Gal4 = AngV_J74_Gal4.flatten()
AngV_J73_Gal4 = AngV_J73_Gal4.flatten()
AngV_J64 = AngV_J64.flatten()
AngV_J72_Gal4 = AngV_J72_Gal4.flatten()
AngV_J76_Gal4 = AngV_J76_Gal4.flatten()

# Perform pairwise t-tests
t_stat_73_74, p_value_73_74 = stats.ttest_ind(AngV_J73_Gal4, AngV_J74_Gal4)
t_stat_74_72, p_value_74_72 = stats.ttest_ind(AngV_J74_Gal4, AngV_J72_Gal4)
t_stat_72_64, p_value_72_64 = stats.ttest_ind(AngV_J72_Gal4, AngV_J64)
t_stat_73_64, p_value_73_64 = stats.ttest_ind(AngV_J73_Gal4, AngV_J64)

# Print t-statistic and p-values
print(f"T-test between J73 and J74: t-stat = {t_stat_73_74:.2f}, p-value = {p_value_73_74:.2e}")
print(f"T-test between J74 and J72: t-stat = {t_stat_74_72:.2f}, p-value = {p_value_74_72:.2e}")
print(f"T-test between J72 and J64: t-stat = {t_stat_72_64:.2f}, p-value = {p_value_72_64:.2e}")
print(f"T-test between J73 and J64: t-stat = {t_stat_73_64:.2f}, p-value = {p_value_73_64:.2e}")


# Perform one-way ANOVA
f_stat, p_value = stats.f_oneway(AngV_J74_Gal4, AngV_J73_Gal4, AngV_J64, AngV_J72_Gal4, AngV_J76_Gal4)

# Print F-statistic and p-value
print(f"ANOVA: F-statistic = {f_stat:.2f}, p-value = {p_value:.2e}")
# Out:
# T-test between J73 and J74: t-stat = -2.81, p-value = 4.93e-03
# T-test between J74 and J72: t-stat = 2.74, p-value = 6.17e-03
# T-test between J72 and J64: t-stat = 2.35, p-value = 1.86e-02
# T-test between J73 and J64: t-stat = 3.32, p-value = 9.06e-04
# ANOVA: F-statistic = 15.44, p-value = 1.25e-12

# %%
# Number of comparisons
n_tests = 4

# Original significance level
alpha = 0.05

# Bonferroni corrected significance level
alpha_corrected = alpha / n_tests

print(f"Bonferroni-corrected significance level: {alpha_corrected:.4f}")

# Checking if the p-values are significant after Bonferroni correction
p_values = [p_value_73_74, p_value_74_72, p_value_72_64, p_value_73_64]

# Results after Bonferroni correction
for i, p_value in enumerate(p_values):
    is_significant = p_value < alpha_corrected
    print(f"T-test {i+1} p-value = {p_value:.2e}, Significant after Bonferroni correction: {is_significant}")
# Out:
# Bonferroni-corrected significance level: 0.0125
# T-test 1 p-value = 4.93e-03, Significant after Bonferroni correction: True
# T-test 2 p-value = 6.17e-03, Significant after Bonferroni correction: True
# T-test 3 p-value = 1.86e-02, Significant after Bonferroni correction: False
# T-test 4 p-value = 9.06e-04, Significant after Bonferroni correction: True

# %%
import pandas as pd
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Combine all the data into a single array and group labels
data = np.concatenate([AngV_J74_Gal4, AngV_J73_Gal4, AngV_J72_Gal4, AngV_J64, AngV_J76_Gal4])
groups = (['J74'] * len(AngV_J74_Gal4) + 
          ['J73'] * len(AngV_J73_Gal4) + 
          ['J72'] * len(AngV_J72_Gal4) + 
          ['J64'] * len(AngV_J64) +
          ['J76'] * len(AngV_J76_Gal4))

# Create a pandas DataFrame
df = pd.DataFrame({'Value': data, 'Group': groups})

# Perform Tukey's HSD test
tukey_result = pairwise_tukeyhsd(endog=df['Value'], groups=df['Group'], alpha=0.05)

# Print the summary of Tukey's test
print(tukey_result)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#    J64    J72  21.6742 0.0788  -1.4617 44.8101  False
#    J64    J73  24.3557 0.0031   5.8277 42.8836   True
#    J64    J74  44.0546    0.0  25.7737 62.3356   True
#    J64    J76  44.0546    0.0  25.7737 62.3356   True
#    J72    J73   2.6815 0.9983 -21.9751 27.3381  False
#    J72    J74  22.3804 0.0918  -2.0911 46.8519  False
#    J72    J76  22.3804 0.0918  -2.0911 46.8519  False
#    J73    J74   19.699 0.0594  -0.4721   39.87  False
#    J73    J76   19.699 0.0594  -0.4721   39.87  False
#    J74    J76      0.0    1.0 -19.9444 19.9444  False
# -----------------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.table import Table

# Tukey HSD Results
data = {
    "Group 1": ["J64", "J64", "J64", "J72", "J72", "J73"],
    "Group 2": ["J72", "J73", "J74", "J73", "J74", "J74"],
    "Mean Difference": [57.78, 95.87, 79.03, 38.09, 21.24, -16.84],
    "Adjusted p-value": [0.001, 0.000, 0.000, 0.000, 0.0005, 0.0405],
    "95% CI (Lower, Upper)": [
        "[18.11, 97.46]",
        "[55.28, 136.47]",
        "[39.32, 118.74]",
        "[21.83, 54.35]",
        "[7.33, 35.16]",
        "[-33.19, -0.50]",
    ],
    "Significant": ["Yes", "Yes", "Yes", "Yes", "Yes", "Yes"]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 4))

# Hide axes
ax.axis('off')

# Create a table
table = Table(ax, bbox=[0, 0, 1, 1])

# Add cells
for i, column in enumerate(df.columns):
    table.add_cell(i + 1, 0, width=0.15, height=0.05, text=column, loc='center', facecolor='lightgray', edgecolor='black')

for i, (index, row) in enumerate(df.iterrows()):
    for j, value in enumerate(row):
        table.add_cell(i + 1, j, width=0.15, height=0.05, text=str(value), loc='center', edgecolor='black')

# Add the table to the axes
ax.add_table(table)

# Set title
ax.set_title('Tukey HSD Test Results', fontsize=16, fontweight='bold')

# Adjust layout
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

# Show the plot
plt.show()

# %%
heading_diffs2 = []
for traj in data2["position"]:
    heading_diffs2.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs2))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate heading differences (already done in your existing code)
heading_diffs2 = []
for traj in data2["position"]:
    heading_diffs2.append(heading_direction_diff(traj, origin=50, end=80, n=10))

# Convert the list to a numpy array
heading_diffs2 = np.array(heading_diffs2)

# Calculate the histogram with bins from -180 to 180
bins = np.arange(-180, 181, 10)  # Adjusting bins to range from -180 to 180, with bin width 10 degrees
hist, bin_edges = np.histogram(heading_diffs2, bins=bins, density=True)

# Calculate the bin centers
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Plot the probability density bar plot
plt.figure(figsize=(10,6))
plt.bar(bin_centers, hist, width=10, edgecolor='black', alpha=0.7)

# Set labels and title
plt.xlabel('Degrees of Heading Difference')
plt.ylabel('Probability Density')
plt.title('Probability Density of Heading Differences (-180° to 180°)')
# Out:
# Text(0.5, 1.0, 'Probability Density of Heading Differences (-180° to 180°)')

# %%
heading_diffs3 = []
for traj in data3["position"]:
    heading_diffs3.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs3))
plt.show()

# %%
# Combine the heading differences from both repeats
heading_diffs_J73 = heading_diffs2 + heading_diffs3

# Plot the combined heading differences
plt.figure()
plt.boxplot(np.abs(heading_diffs_J73))
plt.title("J73_Heading_Diffs")
plt.ylabel("Absolute Heading Differences")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 # Combine the heading differences from both repeats
# ----> 2 heading_diffs_J73 = heading_diffs2 + heading_diffs3
#       4 # Plot the combined heading differences
#       5 plt.figure()
#
# ValueError: operands could not be broadcast together with shapes (71,) (104,)

# %%
# Combine the heading differences from both repeats
heading_diffs_J73 = np.concatenate((heading_diffs2, heading_diffs3))  # Use parentheses

# Plot the combined heading differences
plt.figure()
plt.boxplot(np.abs(heading_diffs_J73))  # Use np.abs() if you want to plot absolute values
plt.title("J73_Heading_Diffs")
plt.ylabel("Absolute Heading Differences")
plt.show()

# %%
# Plot the heading differences side by side
plt.figure(figsize=(10, 6))
plt.boxplot([np.abs(heading_diffs2), np.abs(heading_diffs3)], labels=["Second Repeat", "Third Repeat"])
plt.title("Heading Differences for J73")
plt.ylabel("Absolute Heading Differences (degrees)")
plt.grid(True)
plt.show()

# %%
heading_diffs4 = []
for traj in data4["position"]:
    heading_diffs4.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs4))
plt.show()

# %%
heading_diffs5 = []
for traj in data5["position"]:
    heading_diffs5.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs5))
plt.show()

# %%
heading_diffs6 = []
for traj in data6["position"]:
    heading_diffs6.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs6))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(
    [np.abs(heading_diffs4), np.abs(heading_diffs5), np.abs(heading_diffs6)],
    labels=["First Repeat", "Second Repeat", "Third Repeat"]
)
plt.title("Heading Differences for J74")
plt.ylabel("Absolute Heading Differences (degrees)")
plt.grid(True)
plt.show()

# %%
# Combine the heading differences from both repeats
heading_diffs_J74 = np.concatenate((heading_diffs4, heading_diffs5, heading_diffs6))

# Plot the combined heading differences
plt.figure()
plt.boxplot(np.abs(heading_diffs_J74))
plt.title("J74_Heading_Diffs")
plt.ylabel("Absolute Heading Differences")
plt.show()

# %%
heading_diffs7 = []
for traj in data7["position"]:
    heading_diffs7.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs7))
plt.show()

# %%
heading_diffs8 = []
for traj in data8["position"]:
    heading_diffs8.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs8))
plt.show()

# %%
# Combine the heading differences from both repeats
heading_diffs_J72 = heading_diffs8 + heading_diffs9
# Plot the combined heading differences
plt.figure()
plt.boxplot(np.abs(heading_diffs_J72))
plt.title("J72_Heading_Diffs")
plt.ylabel("Absolute Heading Differences")
plt.show()

# %%
heading_diffs9 = []
for traj in data9["position"]:
    heading_diffs9.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs9))
plt.show()

# %%
heading_diffs10 = []
for traj in data10["position"]:
    heading_diffs10.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs10))
plt.show()

# %%
heading_diffs11 = []
for traj in data11["position"]:
    heading_diffs11.append(heading_direction_diff(traj, origin=50, end=80, n=10))

plt.figure()
plt.boxplot(np.abs(heading_diffs11))
plt.show()

# %%
heading_diffs_J76 = heading_diffs10 + heading_diffs11

# %%
# Calculate means and standard errors
means = [
    np.mean(np.abs(heading_diffs_J74)),
    np.mean(np.abs(heading_diffs_J73)),
    np.mean(np.abs(heading_diffs_J72)),
    np.mean(np.abs(heading_diffs7))
]
std_errors = [
    np.std(np.abs(heading_diffs_J74)) / np.sqrt(len(heading_diffs_J74)),
    np.std(np.abs(heading_diffs_J73)) / np.sqrt(len(heading_diffs_J73)),
    np.std(np.abs(heading_diffs_J72)) / np.sqrt(len(heading_diffs_J72)),
    np.std(np.abs(heading_diffs7)) / np.sqrt(len(heading_diffs7))
]

# Create a boxplot
plt.figure(figsize=(10, 6))
boxplot = plt.boxplot(
    [np.abs(heading_diffs_J74), np.abs(heading_diffs_J73), np.abs(heading_diffs_J72), np.abs(heading_diffs7)], 
    labels=["J74", "J73", "J72", "J64"],
    patch_artist=True,  # For coloring
    boxprops=dict(facecolor='lightblue', color='black'),
    medianprops=dict(color='darkblue'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    flierprops=dict(marker='o', color='red', markersize=5)
)

# Customize colors for each box
colors = ['lightblue', 'lightcoral', 'lightgreen', 'lightsalmon']
for i, patch in enumerate(boxplot['boxes']):
    patch.set_facecolor(colors[i])  # Set different colors for each dataset

# Add mean markers
plt.plot(range(1, 5), means, marker='o', color='green', markersize=10, label='Mean', linestyle='None')

# Add error bars for standard error
plt.errorbar(range(1, 5), means, yerr=std_errors, fmt='none', ecolor='black', capsize=5, label='Standard Error')

# Title and labels
plt.title("Heading Differences Comparison", fontsize=16)
plt.ylabel("Absolute Heading Differences (degrees)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)

# Add legend
plt.legend()
plt.show()

# %%
means = [
    np.mean(np.abs(heading_diffs_J74)),
    np.mean(np.abs(heading_diffs_J73)),
    np.mean(np.abs(heading_diffs_J72)),
    np.mean(np.abs(heading_diffs7))
]
std_errors = [
    np.std(np.abs(heading_diffs_J74)) / np.sqrt(len(heading_diffs_J74)),
    np.std(np.abs(heading_diffs_J73)) / np.sqrt(len(heading_diffs_J73)),
    np.std(np.abs(heading_diffs_J72)) / np.sqrt(len(heading_diffs_J72)),
    np.std(np.abs(heading_diffs7)) / np.sqrt(len(heading_diffs7))
]

# %%
plt.figure(figsize=(16, 10))

# Corrected the typo and removed the extra parenthesis
boxplot = plt.boxplot(
    [np.abs(heading_diffs_J74), np.abs(heading_diffs_J73), np.abs(heading_diffs_J72), np.abs(heading_diffs7), np.abs(heading_diffs_J76)], 
    labels=[ "DNa05/03", "DNa05/07", "DNa05/07", "empty_splitGal4", "DNp11"],
    patch_artist=True,  # For coloring
    boxprops=dict(facecolor='lightblue', color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    flierprops=dict(marker='o', color='red', markersize=5)
)

# Calculate means and standard deviations directly from the data
means = [
    np.mean(np.abs(heading_diffs_J74)),
    np.mean(np.abs(heading_diffs_J73)),
    np.mean(np.abs(heading_diffs_J72)),
    np.mean(np.abs(heading_diffs7)),
    np.mean(np.abs(heading_diffs_J76))
]

stds = [
    np.std(np.abs(heading_diffs_J74)),
    np.std(np.abs(heading_diffs_J73)),
    np.std(np.abs(heading_diffs_J72)),
    np.std(np.abs(heading_diffs7)),
    np.std(np.abs(heading_diffs_J76))
]

# Add mean markers
plt.plot([1, 2, 3, 4, 5], means, marker='o', color='orange', markersize=10, label='Mean', linestyle='None',)

# Add error bars for standard deviation
plt.errorbar([1, 2, 3, 4, 5], means, yerr=stds, fmt='none', ecolor='orange', capsize=5, label='Standard Deviation',)

# Title and labels
plt.title("Heading Differences Comparison", fontsize=23)
plt.ylabel("Absolute Heading Differences (degrees)", fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(False)
plt.legend(fontsize=24, title_fontsize=20)

# Add legend
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming your data (heading_diffs_J74, heading_diffs_J73, etc.) is already defined

plt.figure(figsize=(16, 10))

# Create the boxplot
boxplot = plt.boxplot(
    [np.abs(heading_diffs_J74), np.abs(heading_diffs_J73), np.abs(heading_diffs_J72), np.abs(heading_diffs7), np.abs(heading_diffs_J76)], 
    labels=["DNa05/03", "DNa05/07", "DNa05/07", "empty_splitGal4", "DNp11"],
    patch_artist=True,  # For coloring
    boxprops=dict(facecolor='lightblue', color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    flierprops=dict(marker='o', color='red', markersize=5),
    medianprops=dict(color= 'none')
)

# Calculate means and standard deviations directly from the data
means = [
    np.mean(np.abs(heading_diffs_J74)),
    np.mean(np.abs(heading_diffs_J73)),
    np.mean(np.abs(heading_diffs_J72)),
    np.mean(np.abs(heading_diffs7)),
    np.mean(np.abs(heading_diffs_J76))
]

stds = [
    np.std(np.abs(heading_diffs_J74)),
    np.std(np.abs(heading_diffs_J73)),
    np.std(np.abs(heading_diffs_J72)),
    np.std(np.abs(heading_diffs7)),
    np.std(np.abs(heading_diffs_J76))
]

# Add mean markers
mean_line, = plt.plot([1, 2, 3, 4, 5], means, marker='o', color='orange', markersize=10, label='Mean', linestyle='None')

# Add error bars for standard deviation
error_bar = plt.errorbar([1, 2, 3, 4, 5], means, yerr=stds, fmt='none', ecolor='orange', capsize=5, label='Standard Deviation')

# Title and labels
plt.title("Heading Differences Comparison", fontsize=25)
plt.ylabel("Absolute Heading Differences (degrees)", fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(False)

# Add legend with increased font size
legend = plt.legend(fontsize=20)  # Adjust legend font size here

# Update font size of each legend item directly if needed
for text in legend.get_texts():
    text.set_fontsize(20)

# Add legend in the top-right corner
legend = plt.legend(fontsize=20, loc='upper right')  # Change loc to 'upper right

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd

# Calculate descriptive statistics for each dataset
stats_J74 = {
    'Mean': np.mean(np.abs(heading_diffs_J74)),
    'Median': np.median(np.abs(heading_diffs_J74)),
    'Std Dev': np.std(np.abs(heading_diffs_J74)),
    'Min': np.min(np.abs(heading_diffs_J74)),
    'Max': np.max(np.abs(heading_diffs_J74))
}

stats_J73 = {
    'Mean': np.mean(np.abs(heading_diffs_J73)),
    'Median': np.median(np.abs(heading_diffs_J73)),
    'Std Dev': np.std(np.abs(heading_diffs_J73)),
    'Min': np.min(np.abs(heading_diffs_J73)),
    'Max': np.max(np.abs(heading_diffs_J73))
}

stats_J72 = {
    'Mean': np.mean(np.abs(heading_diffs_J72)),
    'Median': np.median(np.abs(heading_diffs_J72)),
    'Std Dev': np.std(np.abs(heading_diffs_J72)),
    'Min': np.min(np.abs(heading_diffs_J72)),
    'Max': np.max(np.abs(heading_diffs_J72))
}

stats_J64 = {
    'Mean': np.mean(np.abs(heading_diffs7)),  # Assuming heading_diffs7 refers to J64
    'Median': np.median(np.abs(heading_diffs7)),
    'Std Dev': np.std(np.abs(heading_diffs7)),
    'Min': np.min(np.abs(heading_diffs7)),
    'Max': np.max(np.abs(heading_diffs7))
}

stats_J76 = {
    'Mean': np.mean(np.abs(heading_diffs_J76)),
    'Median': np.median(np.abs(heading_diffs_J76)),
    'Std Dev': np.std(np.abs(heading_diffs_J76)),
    'Min': np.min(np.abs(heading_diffs_J76)),
    'Max': np.max(np.abs(heading_diffs_J76))
}

# Create a DataFrame to display the statistics for all datasets
stats_df = pd.DataFrame({
    'J74': stats_J74,
    'J73': stats_J73,
    'J72': stats_J72,
    'J64': stats_J64,
    'J76': stats_J76
})

# Display the DataFrame
print(stats_df)
# Out:
#                 J74         J73         J72         J64         J76
# Mean      88.626255   81.761057   54.921757   70.880770   57.666842
# Median    90.227783   72.016269   40.763675   72.745205   49.272821
# Std Dev   52.700407   54.504012   48.807512   45.871856   46.595541
# Min        0.021626    0.321592    0.405768    0.840679    0.648634
# Max      179.913142  178.888157  179.090574  176.231236  178.056227

# %%
import numpy as np
import matplotlib.pyplot as plt

# Updated descriptive statistics data for all datasets
data = {
    'Statistics': ['Mean', 'Median', 'Std Dev', 'Min', 'Max'],
    'J74': [88.626255, 90.227783, 52.700407, 0.021626, 179.913142],
    'J73': [81.761057, 72.016269, 54.504012, 0.321592, 178.888157],
    'J72': [54.921757, 40.763675, 48.807512, 0.405768, 179.090574],
    'J64': [70.880770, 72.745205, 45.871856, 0.840679, 176.231236],
    'J76': [57.666842, 49.272821, 46.595541, 0.648634, 178.056227]
}

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Hide the axes
ax.axis('tight')
ax.axis('off')

# Prepare the table data as a numpy array
table_data = np.array([
    data['Statistics'],
    data['J74'],
    data['J73'],
    data['J72'],
    data['J64'],
    data['J76']
]).T

# Create the table
table = ax.table(cellText=table_data,
                 colLabels=['Statistics', 'J74', 'J73', 'J72', 'J64', 'J76'],
                 cellLoc='center',
                 loc='center')

# Customize the table
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)

# Add color to the header
for (i, j), cell in table.get_celld().items():
    if i == 0:  # Header row
        cell.set_facecolor('#4CAF50')  # Green color
        cell.set_text_props(color='white')  # White text
    else:
        if j == 0:  # First column (Statistics)
            cell.set_facecolor('#f2f2f2')  # Light gray for first column
        elif j == 1:  # Second column (J74)
            cell.set_facecolor('#e3f2fd')  # Light blue for J74
        elif j == 2:  # Third column (J73)
            cell.set_facecolor('#ffebee')  # Light red for J73
        elif j == 3:  # Fourth column (J72)
            cell.set_facecolor('#e8f5e9')  # Light green for J72
        elif j == 4:  # Fifth column (J64)
            cell.set_facecolor('#fff3e0')  # Light orange for J64
        elif j == 5:  # Sixth column (J76)
            cell.set_facecolor('#fce4ec')  # Light pink for J76

# Add borders
for (i, j), cell in table.get_celld().items():
    cell.set_edgecolor('black')  # Set border color
    cell.set_linewidth(1)  # Set border width

# Set title
plt.title("Descriptive Statistics for Heading Differences", fontsize=16, fontweight='bold')

# Show the plot
plt.show()

# %%
# Assuming the heading differences for the four groups are already calculated and stored in:
# headingdiffs_J73, headingdiffs_J74, headingdiffs_J76, headingdiffs_J72

# Group the data together for easy iteration
heading_diffs_groups = [heading_diffs_J73, heading_diffs_J74, heading_diffs_J76, heading_diffs_J72]
group_names = ['J73', 'J74', 'J76', 'J72']
colors = ['blue', 'green', 'red', 'orange']  # Define a unique color for each group

# Create the figure and a 1x4 grid of subplots (side by side)
fig, axs = plt.subplots(1, 4, figsize=(20, 5), sharey=True)  # 1x4 grid, share Y-axis

bins = np.arange(-180, 181, 10)  # Bins from -180 to 180 degrees with a width of 10 degrees

# Iterate through each group and corresponding subplot
for i, (heading_diffs, ax, name, color) in enumerate(zip(heading_diffs_groups, axs, group_names, colors)):
    # Calculate the histogram and normalize to get the probability density
    hist, bin_edges = np.histogram(heading_diffs, bins=bins, density=True)
    
    # Calculate the bin centers for plotting
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Plot the bar plot on the current subplot
    ax.bar(bin_centers, hist, width=10, edgecolor='black', alpha=0.7, color=color)
    
    # Set subplot labels and title
    ax.set_xlabel('Degrees')
    ax.set_title(f'Group {name}')
    ax.grid(True)

# Set the common y-axis label for all subplots
axs[0].set_ylabel('Probability Density')

# Adjust layout to prevent overlap of subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Assuming the heading differences for the four groups are already calculated and stored in:
# headingdiffs_J73, headingdiffs_J74, headingdiffs_J76, headingdiffs_J72

# Group the data together for easy iteration
heading_diffs_groups = [heading_diffs_J73, heading_diffs_J74, heading_diffs_J76, heading_diffs_J72, heading_diffs7]
group_names = ['(DNa05/07)', '(DNa05/03)', '(DNp11)', '(DNa05/07)', 'empty_splitGal4']
colors = ['blue', 'green', 'red', 'orange', 'black']  # Define colors for each group


# Iterate through the groups and plot each one with its label and color
for group, name, color in zip(heading_diffs_groups, group_names, colors):
    ax.plot(group, color=color, label= 'Experiment Index')  # Add label for the legend

# Create a single figure
plt.figure(figsize=(16, 12))

bins = np.arange(-180, 180, 10)  # Bins from -180 to 180 degrees with a width of 10 degrees
bin_width = 10  # Width for each bar

# Number of groups to compare
n_groups = len(heading_diffs_groups)

# Create the plot with bars shifted slightly to the side for each group
for i, (heading_diffs, name, color) in enumerate(zip(heading_diffs_groups, group_names, colors)):
    # Calculate the histogram and normalize to get the probability density
    hist, bin_edges = np.histogram(heading_diffs, bins=bins, density=True)
    
    # Calculate the bin centers
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Shift the bars slightly based on the group index 'i'
    offset = (i - n_groups/2) * bin_width / n_groups  # Shift to the left or right depending on index
    plt.bar(bin_centers + offset, hist, width=bin_width/n_groups, edgecolor='black', alpha=0.7, color=color, label=f'Group {name}')

# Set the plot labels and title
plt.xlabel('Degrees of Heading Difference', fontsize = 22)
plt.ylabel('Probability Density', fontsize = 22)
plt.title('Probability Density of Heading Differences', fontsize = 26)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(False)

ax.legend(title="Experiment Index", fontsize = 20)

# Add a legend to differentiate the groups

plt.legend(title="Experiment Index", fontsize=24, title_fontsize=26)  # Legend with custom font size
plt.legend()

# Add grid for clarity
plt.grid(True)

plt.grid(False)

# Show the plot
plt.show()

# %%
# Assuming the heading differences for the four groups are already calculated and stored in:
# heading_diffs_J73, heading_diffs_J74, heading_diffs_J76, heading_diffs_J72, heading_diffs7

# Group the data together for easy iteration
heading_diffs_groups = [heading_diffs_J73, heading_diffs_J74, heading_diffs_J76, heading_diffs_J72, heading_diffs7]
group_names = ['(DNa05/07)', '(DNa05/03)', '(DNp11)', '(DNa05/07)', 'emptysplit-Gal4']
colors = ['blue', 'green', 'red', 'orange', 'black']  # Define colors for each group

# Create a single figure
plt.figure(figsize=(14, 10))

bins = np.arange(-180, 180, 10)  # Bins from -180 to 180 degrees with a width of 10 degrees
bin_width = 10  # Width for each bar

# Number of groups to compare
n_groups = len(heading_diffs_groups)

# Create the plot with bars shifted slightly to the side for each group
for i, (heading_diffs, name, color) in enumerate(zip(heading_diffs_groups, group_names, colors)):
    # Calculate the histogram and normalize to get the probability density
    hist, bin_edges = np.histogram(heading_diffs, bins=bins, density=True)
    
    # Calculate the bin centers
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    
    # Shift the bars slightly based on the group index 'i'
    offset = (i - n_groups/2) * bin_width / n_groups  # Shift to the left or right depending on index
    plt.bar(bin_centers + offset, hist, width=bin_width/n_groups, edgecolor='black', alpha=0.7, color=color, label=name)

# Set the plot labels and title
plt.xlabel('Degrees of Heading Difference', fontsize=20)
plt.ylabel('Probability Density', fontsize=20)
plt.title('Probability Density of Heading Differences', fontsize=24)

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Add a legend to differentiate the groups
plt.legend(title="Experiment Index", fontsize=16, title_fontsize=18)  # Legend with custom font size

# Add grid for clarity
plt.grid(False)

# Show the plot
plt.show()

# %%
# Find the maximum length among all arrays
max_length = max(len(heading_diffs_J73), len(heading_diffs_J74), len(heading_diffs_J76), len(heading_diffs_J72))

# Pad shorter arrays with NaN
heading_diffs_J73 = np.pad(heading_diffs_J73, (0, max_length - len(heading_diffs_J73)), constant_values=np.nan)
heading_diffs_J74 = np.pad(heading_diffs_J74, (0, max_length - len(heading_diffs_J74)), constant_values=np.nan)
heading_diffs_J76 = np.pad(heading_diffs_J76, (0, max_length - len(heading_diffs_J76)), constant_values=np.nan)
heading_diffs_J72 = np.pad(heading_diffs_J72, (0, max_length - len(heading_diffs_J72)), constant_values=np.nan)

# %%
data = pd.DataFrame({
    'J73': heading_diffs_J73,
    'J74': heading_diffs_J74,
    'J76': heading_diffs_J76,
    'J72': heading_diffs_J72
})

# %%
mean_heading_diffs = data.mean()

# %%
heading_diffs_J73 = np.abs(heading_diffs_J73)
heading_diffs_J74 = np.abs(heading_diffs_J74)
heading_diffs_J76 = np.abs(heading_diffs_J76)
heading_diffs_J72 = np.abs(heading_diffs_J72)

# %%
# Find the maximum length among all arrays
max_length = max(len(heading_diffs_J73), len(heading_diffs_J74), len(heading_diffs_J76), len(heading_diffs_J72))

# Pad shorter arrays with NaN
heading_diffs_J73 = np.pad(heading_diffs_J73, (0, max_length - len(heading_diffs_J73)), constant_values=np.nan)
heading_diffs_J74 = np.pad(heading_diffs_J74, (0, max_length - len(heading_diffs_J74)), constant_values=np.nan)
heading_diffs_J76 = np.pad(heading_diffs_J76, (0, max_length - len(heading_diffs_J76)), constant_values=np.nan)
heading_diffs_J72 = np.pad(heading_diffs_J72, (0, max_length - len(heading_diffs_J72)), constant_values=np.nan)

# %%
data = pd.DataFrame({
    'J73': heading_diffs_J73,
    'J74': heading_diffs_J74,
    'J76': heading_diffs_J76,
    'J72': heading_diffs_J72
})

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data.T, cmap='coolwarm', annot= False, fmt=".2f")  # Transpose to have group labels on the y-axis
plt.title('Heatmap of Absolute Heading Differences')
plt.xlabel('Sample Index')
plt.ylabel('Groups')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure all heading differences are absolute values
heading_diffs_J73 = np.abs(heading_diffs_J73)
heading_diffs_J74 = np.abs(heading_diffs_J74)
heading_diffs_J76 = np.abs(heading_diffs_J76)
heading_diffs_J72 = np.abs(heading_diffs_J72)

# Ensure all arrays have the same length (if needed)
min_length = min(len(heading_diffs_J73), len(heading_diffs_J74), len(heading_diffs_J76), len(heading_diffs_J72))

# Reduce the data size by selecting a smaller subset of the data
subset_indices = np.linspace(0, min_length-1, num=100, dtype=int)  # Select 100 evenly spaced points
heading_diffs_J73 = heading_diffs_J73[subset_indices]
heading_diffs_J74 = heading_diffs_J74[subset_indices]
heading_diffs_J76 = heading_diffs_J76[subset_indices]
heading_diffs_J72 = heading_diffs_J72[subset_indices]

# Create a DataFrame with the absolute values
data = pd.DataFrame({
    'J73': heading_diffs_J73,
    'J74': heading_diffs_J74,
    'J76': heading_diffs_J76,
    'J72': heading_diffs_J72
})

# Create the simplified heatmap
plt.figure(figsize=(12, 6))  # Increase the size for better readability
sns.heatmap(data.T, cmap='coolwarm', cbar=True, annot=False, linewidths=0.5, linecolor='white')  # Remove annotations, add lines between cells
plt.title('Simplified Heatmap of Absolute Heading Differences')
plt.xlabel('Sample Index')
plt.ylabel('Groups')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure all heading differences are absolute values
heading_diffs_J73 = np.abs(heading_diffs_J73)
heading_diffs_J74 = np.abs(heading_diffs_J74)
heading_diffs_J76 = np.abs(heading_diffs_J76)
heading_diffs_J72 = np.abs(heading_diffs_J72)

# Ensure all arrays have the same length
min_length = min(len(heading_diffs_J73), len(heading_diffs_J74), len(heading_diffs_J76), len(heading_diffs_J72))

# Truncate data to the minimum length if necessary
heading_diffs_J73 = heading_diffs_J73[:min_length]
heading_diffs_J74 = heading_diffs_J74[:min_length]
heading_diffs_J76 = heading_diffs_J76[:min_length]
heading_diffs_J72 = heading_diffs_J72[:min_length]

# Create a DataFrame with the absolute values
data = pd.DataFrame({
    'J73': heading_diffs_J73,
    'J74': heading_diffs_J74,
    'J76': heading_diffs_J76,
    'J72': heading_diffs_J72
})

# Create the heatmap
plt.figure(figsize=(12, 6))  # Increase the figure size for better readability
sns.heatmap(data.T, cmap='coolwarm', cbar=True, annot=False, linewidths=0.5, linecolor='white')  # Remove annotations
plt.title('Heatmap of Absolute Heading Differences Without Annotations')
plt.xlabel('Sample Index')
plt.ylabel('Groups')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure all heading differences are absolute values
heading_diffs_J73 = np.abs(heading_diffs_J73)
heading_diffs_J74 = np.abs(heading_diffs_J74)
heading_diffs_J76 = np.abs(heading_diffs_J76)
heading_diffs_J72 = np.abs(heading_diffs_J72)

# Ensure all arrays have the same length
min_length = min(len(heading_diffs_J73), len(heading_diffs_J74), len(heading_diffs_J76), len(heading_diffs_J72))

# Truncate data to the minimum length if necessary
heading_diffs_J73 = heading_diffs_J73[:min_length]
heading_diffs_J74 = heading_diffs_J74[:min_length]
heading_diffs_J76 = heading_diffs_J76[:min_length]
heading_diffs_J72 = heading_diffs_J72[:min_length]

# Create a DataFrame with the absolute values
data = pd.DataFrame({
    'J73': heading_diffs_J73,
    'J74': heading_diffs_J74,
    'J76': heading_diffs_J76,
    'J72': heading_diffs_J72
})

# Create the heatmap with padding
plt.figure(figsize=(12, 6))  # Set figure size
sns.heatmap(data.T, cmap='coolwarm', cbar=True, annot=False, 
            linewidths=0.5, linecolor='white', square=False)  # square=False allows more flexibility

# Add padding around the heatmap using tight_layout and adjust subplots
plt.title('Heatmap of Absolute Heading Differences with Padding')
plt.xlabel('Sample Index')
plt.ylabel('Groups')

# Use tight layout to add padding
plt.tight_layout(pad=3.0)  # Padding value for the plot
plt.show()

# %%
# Step 1: Create a DataFrame with the heading differences
data = pd.DataFrame({
    'J73': heading_diffs_J73,
    'J74': heading_diffs_J74,
    'J76': heading_diffs_J76,
    'J72': heading_diffs_J72
})

# Step 2: Check for NaN or infinite values and clean the data
# Check for NaN values
print("NaN values in each column before cleaning:")
print(data.isna().sum())

# Replace NaN values with the column mean
data_clean = data.apply(lambda x: np.nan_to_num(x, nan=np.nanmean(x)))

# Check for infinite values
print("Checking for infinite values:")
print(np.isfinite(data_clean).all())

# Remove any infinite values (if any exist)
data_clean = data_clean.replace([np.inf, -np.inf], np.nan)  # Replace infinities with NaN
data_clean = data_clean.dropna()  # Drop rows with NaN or infinite values

# Step 3: Generate the clustered heatmap
sns.clustermap(data_clean.T, cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='white')

# Display the heatmap
plt.show()
# Out:
# NaN values in each column before cleaning:
# J73    42
# J74     0
# J76    39
# J72    69
# dtype: int64
# Checking for infinite values:
# J73    True
# J74    True
# J76    True
# J72    True
# dtype: bool

# %%
plt.figure(figsize=(12, 8))

# Plot each group's heading differences over the index (assuming it's time or sample number)
plt.plot(data.index, data['J73'], label='J73', color='blue')
plt.plot(data.index, data['J74'], label='J74', color='green')
plt.plot(data.index, data['J76'], label='J76', color='red')
plt.plot(data.index, data['J72'], label='J72', color='purple')

# Customizing the plot
plt.title('Time Series of Heading Differences for Each Group')
plt.xlabel('Sample Index (or Time)')
plt.ylabel('Heading Difference')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title('Boxplot of Heading Differences Across Groups')
plt.ylabel('Heading Difference')
plt.show()

# %%
# Create a DataFrame
data = pd.DataFrame({
    'HeadingDiff': np.concatenate([heading_diffs_J73, heading_diffs_J74, heading_diffs_J76, heading_diffs_J72]),
    'Group': ['J73'] * 100 + ['J74'] * 100 + ['J76'] * 100 + ['J72'] * 100
})

# Check the data types
print(data.dtypes)

# Ensure the HeadingDiff column is numeric
data['HeadingDiff'] = pd.to_numeric(data['HeadingDiff'], errors='coerce')

# Check for any missing values
print(data.isnull().sum())
# Out:
# HeadingDiff    float64
# Group           object
# dtype: object
# HeadingDiff    150
# Group            0
# dtype: int64

# %%
# Ensure all angular velocities are absolute values
angular_velocity_J73 = np.abs(AngV_J73_Gal4)
angular_velocity_J74 = np.abs(AngV_J74_Gal4)
angular_velocity_J76 = np.abs(AngV_J76_Gal4)
angular_velocity_J72 = np.abs(AngV_J72_Gal4)

# Ensure all arrays have the same length (if needed)
min_length = min(len(angular_velocity_J73), len(angular_velocity_J74), len(angular_velocity_J76), len(angular_velocity_J72))

# Reduce the data size by selecting a smaller subset of the data
subset_indices = np.linspace(0, min_length-1, num=20, dtype=int)  # Select 20 evenly spaced points
angular_velocity_J73 = angular_velocity_J73[subset_indices]
angular_velocity_J74 = angular_velocity_J74[subset_indices]
angular_velocity_J76 = angular_velocity_J76[subset_indices]
angular_velocity_J72 = angular_velocity_J72[subset_indices]

# Create a DataFrame with the absolute values of angular velocities
data = pd.DataFrame({
    'J73': angular_velocity_J73,
    'J74': angular_velocity_J74,
    'J76': angular_velocity_J76,
    'J72': angular_velocity_J72
})

# Create the simplified heatmap
plt.figure(figsize=(12, 6))  # Increase the size for better readability
sns.heatmap(data.T, cmap='coolwarm', cbar=True, annot=False, linewidths=0.5, linecolor='white')  # Remove annotations, add lines between cells
plt.title('Simplified Heatmap of Absolute Angular Velocities')
plt.xlabel('Sample Index')
plt.ylabel('Groups')
plt.show()
