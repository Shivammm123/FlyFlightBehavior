# %%
import datetime
import matplotlib.pyplot as plt
from timestamp_convert import convert_timestamp

# %%
unix_timestamps = [1731174827, 1731175862, 1731176056, 1731176120, 1731176164, 1731176781, 1731176791, 1731176877, 1731176940, 1731177111, 1731177145, 1731177258, 1731177526, 1731178224, 1731178498, 1731178574, 1731178582, 1731178698, 1731178860, 1731180073, 1731180486, 1731180662, 1731180728, 1731180755, 1731180885, 1731180924, 1731181300, 1731182051, 1731182439, 1731182444, 1731182582, 1731182631, 1731182910, 1731183016, 1731183316, 1731183405, 1731183703, 1731183984, 1731184141, 1731184154, 1731184222, 1731184493, 1731184762, 1731185111, 1731185196, 1731185660, 1731186017, 1731186698, 1731186985, 1731187237, 1731187405, 1731187506, 1731187621, 1731187952, 1731188286, 1731188401, 1731189476, 1731189505, 1731189555, 1731189675, 1731189776, 1731189787, 1731189868, 1731190026, 1731190035, 1731190338, 1731190629, 1731190643, 1731190656, 1731190695, 1731190821, 1731190980, 1731191025, 1731191448, 1731191878, 1731192040, 1731192518, 1731192589, 1731192960, 1731193019, 1731193079, 1731193115, 1731193170, 1731193291, 1731193485, 1731193557, 1731193760, 1731193919, 1731194034, 1731194304, 1731194318, 1731194607, 1731194804, 1731194813, 1731195114, 1731195190, 1731195245, 1731195264, 1731195288, 1731195326, 1731195444, 1731195707, 1731196175, 1731196501, 1731196601, 1731197041, 1731197058, 1731197514, 1731197718, 1731197947, 1731198282, 1731198899, 1731198972, 1731199258, 1731199300, 1731199590, 1731200102, 1731200208, 1731200751, 1731200766, 1731201165, 1731201571, 1731202068, 1731202149, 1731202998, 1731203863, 1731204445, 1731204501, 1731205462, 1731205803, 1731205930, 1731205994, 1731207021, 1731207142, 1731207220, 1731207884, 1731207896, 1731207981, 1731208462, 1731208626, 1731208885, 1731209056, 1731209275, 1731209641, 1731209913, 1731210160, 1731210516, 1731211060, 1731211120, 1731211797, 1731211908, 1731212466, 1731213021, 1731213252, 1731213310, 1731214843, 1731215551, 1731216040, 1731218842, 1731219113, 1731219187, 1731220223, 1731220228, 1731221489, 1731221882, 1731223036, 1731223358, 1731224816, 1731226192, 1731226590, 1731228870, 1731230149, 1731230260, 1731233176, 1731234537, 1731235188, 1731235432, 1731237669, 1731237812, 1731240322, 1731241828, 1731245673, 1731251013, 1731255334, 1731259089
]
human_readable_dates = [convert_timestamp(ts) for ts in unix_timestamps]
for timestamp, human_readable_date in zip(unix_timestamps, human_readable_dates):
    print(f"Unix Timestamp: {timestamp} -> Human-Readable Time: {human_readable_date}")
# Out:
# Unix Timestamp: 1731174827 -> Human-Readable Time: 2024-11-09 18:53:47
# Unix Timestamp: 1731175862 -> Human-Readable Time: 2024-11-09 19:11:02
# Unix Timestamp: 1731176056 -> Human-Readable Time: 2024-11-09 19:14:16
# Unix Timestamp: 1731176120 -> Human-Readable Time: 2024-11-09 19:15:20
# Unix Timestamp: 1731176164 -> Human-Readable Time: 2024-11-09 19:16:04
# Unix Timestamp: 1731176781 -> Human-Readable Time: 2024-11-09 19:26:21
# Unix Timestamp: 1731176791 -> Human-Readable Time: 2024-11-09 19:26:31
# Unix Timestamp: 1731176877 -> Human-Readable Time: 2024-11-09 19:27:57
# Unix Timestamp: 1731176940 -> Human-Readable Time: 2024-11-09 19:29:00
# Unix Timestamp: 1731177111 -> Human-Readable Time: 2024-11-09 19:31:51
# Unix Timestamp: 1731177145 -> Human-Readable Time: 2024-11-09 19:32:25
# Unix Timestamp: 1731177258 -> Human-Readable Time: 2024-11-09 19:34:18
# Unix Timestamp: 1731177526 -> Human-Readable Time: 2024-11-09 19:38:46
# ...

# %%
elapsed_hours = [(ts - unix_timestamps[0]) / 3600 for ts in unix_timestamps]
plt.figure(figsize=(10, 6))
plt.plot(elapsed_hours, human_readable_dates, marker='o', linestyle='-', color='b')
plt.xlabel('Hours from First Timestamp')
plt.ylabel('Converted Time (YYYY-MM-DD HH:MM:SS)')
plt.title('Converted Times as a Function of Hours from the First Timestamp')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calculate elapsed hours from the first timestamp
elapsed_hours = [(ts - unix_timestamps[0]) / 3600 for ts in unix_timestamps]

# Filter data for the first ten hours
filtered_elapsed_hours = [hour for hour in elapsed_hours if hour <= 10]
filtered_human_readable_dates = [human_readable_dates[i] for i, hour in enumerate(elapsed_hours) if hour <= 10]

# Plot the filtered data
plt.figure(figsize=(10, 6))
plt.plot(filtered_elapsed_hours, filtered_human_readable_dates, marker='o', linestyle='-', color='b')
plt.xlabel('Hours from First Timestamp')
plt.ylabel('Converted Time (YYYY-MM-DD HH:MM:SS)')
plt.title('Converted Times as a Function of Hours from the First Timestamp')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calculate elapsed hours from the first timestamp
elapsed_hours = [(ts - unix_timestamps[0]) / 3600 for ts in unix_timestamps]

# Filter data for the first ten hours
filtered_elapsed_hours1 = [hour for hour in elapsed_hours if hour <= 5]
filtered_human_readable_dates1 = [human_readable_dates[i] for i, hour in enumerate(elapsed_hours) if hour <= 5]

# Plot the filtered data
plt.figure(figsize=(10, 6))
plt.plot(filtered_elapsed_hours, filtered_human_readable_dates, marker='o', linestyle='-', color='b')
plt.xlabel('Hours from First Timestamp')
plt.ylabel('Converted Time (YYYY-MM-DD HH:MM:SS)')
plt.title('Converted Times as a Function of Hours from the First Timestamp')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calculate the number of timestamps within the first ten hours
num_timestamps_first_ten_hours = len(filtered_elapsed_hours)
print(f"Number of timestamps in the first ten hours: {num_timestamps_first_ten_hours}")
# Out:
# Number of timestamps in the first ten hours: 78

# %%
num_timestamps_first_five_hours = len(filtered_elapsed_hours1)
print(f"Number of timestamps in the first five hours: {num_timestamps_first_five_hours}")
# Out:
# Number of timestamps in the first five hours: 78

# %%
# Calculate elapsed hours from the first timestamp
elapsed_hours = [(ts - unix_timestamps[0]) / 3600 for ts in unix_timestamps]

# Print the elapsed hours to verify the data
print("Elapsed hours from the first timestamp:", elapsed_hours)

# Filter and count timestamps within the first five hours
filtered_elapsed_hours_five = [hour for hour in elapsed_hours if hour <= 5]
num_timestamps_first_five_hours = len(filtered_elapsed_hours_five)
print(f"Number of timestamps in the first five hours: {num_timestamps_first_five_hours}")

# Filter and count timestamps within the first ten hours
filtered_elapsed_hours_ten = [hour for hour in elapsed_hours if hour <= 10]
num_timestamps_first_ten_hours = len(filtered_elapsed_hours_ten)
print(f"Number of timestamps in the first ten hours: {num_timestamps_first_ten_hours}")

# Optional: Print the filtered lists to see exactly where timestamps fall
print("Timestamps within the first five hours:", filtered_elapsed_hours_five)
print("Timestamps within the first ten hours:", filtered_elapsed_hours_ten)
# Out:
# Elapsed hours from the first timestamp: [0.0, 0.2875, 0.3413888888888889, 0.3591666666666667, 0.3713888888888889, 0.5427777777777778, 0.5455555555555556, 0.5694444444444444, 0.5869444444444445, 0.6344444444444445, 0.6438888888888888, 0.6752777777777778, 0.7497222222222222, 0.9436111111111111, 1.0197222222222222, 1.0408333333333333, 1.0430555555555556, 1.0752777777777778, 1.1202777777777777, 1.4572222222222222, 1.5719444444444444, 1.6208333333333333, 1.6391666666666667, 1.6466666666666667, 1.6827777777777777, 1.6936111111111112, 1.7980555555555555, 2.006666666666667, 2.1144444444444446, 2.1158333333333332, 2.154166666666667, 2.167777777777778, 2.245277777777778, 2.274722222222222, 2.3580555555555556, 2.3827777777777777, 2.4655555555555555, 2.5436111111111113, 2.587222222222222, 2.5908333333333333, 2.609722222222222, 2.685, 2.7597222222222224, 2.8566666666666665, 2.8802777777777777, 3.0091666666666668, 3.1083333333333334, 3.2975, 3.377222222222222, 3.4472222222222224, 3.493888888888889
# ...
